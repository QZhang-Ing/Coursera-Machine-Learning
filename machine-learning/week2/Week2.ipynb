# %% [markdown]
# # Machine Learning @ Coursera Stanford University

# %% [markdown]
# ## Multiple Variables Linear Regression

# %% [markdown]
# These multiple variables indicates multiple features of the regression problem:
# such as basic price of a house, price per square meters adn number of rooms, etc.

# %% [markdown]
# So, the gradient descent equation itself is generally the same form; we just have to repeat it for our 'n' features.

# %%
from IPython.display import Image
Image("img/multi.png")

# %% [markdown]
# ## Spead up the convergency by Feature Scaling

# %% [markdown]
# We can speed up gradient descent by having each of our input values in roughly the same range.
# Two techniques to help with this are **feature scaling and mean normalization**.

# %% [markdown]
# ### Feature Scaling
#
# dividing the input variables by the range (max - min).

# %% [markdown]
# ### Mean Normalization
# subtracting the average value

# %% [markdown]
# ## Features and Polynomial Regression

# %% [markdown]
# By combining features together wo can change the behavior or curve of the hypothesis function to non linear function.

# %% [markdown]
# # Normal Equation

# %% [markdown]
# Normal equation is a second way to minimize cost function.
#
# Meaning: take J's derivatives == 0 -> theta. Get the optimum theta without iterations.

# %%
Image("img/normalequ.png")

# %%
Image("img/compare.png")

# %% [markdown]
# Take notes that XtX could be noninvertible when:
# 1. redundant features. Features are dependent
# 2. Too many features (n >= m)
